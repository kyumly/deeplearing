# %%
import torch.nn.functional as F
import torch.nn as nn
import torch

class my_model(torch.nn.Module):
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(1,1)

    def forward(self, x):
        y_pred = F.sigmoid(self.linear(x))
        return y_pred


model = my_model()
criterion = nn.BCELoss(size_average=True)
optimizer = torch.optim.SGD(model.parameters(), lr=0.001)

# %%
x_data = torch.Tensor([1.0, 2.0, 3.0, 4.0])
x_data = x_data.view(-1,1)
y_data  = torch.Tensor([0.0, 0.0, 1.0, 1.0]).view(-1,1)
x_data.shape, y_data.shape
# Out:
# (torch.Size([4, 1]), torch.Size([4, 1]))

# %%
losses = []
for epoch in range(1000):
    y_pred = model(x_data)
    loss = criterion(y_pred, y_data)
    print('loss : ' , loss.data)
    losses.append(loss.data.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# loss :  tensor(0.9120)
# loss :  tensor(0.9116)
# loss :  tensor(0.9112)
# loss :  tensor(0.9108)
# loss :  tensor(0.9104)
# loss :  tensor(0.9100)
# loss :  tensor(0.9096)
# loss :  tensor(0.9093)
# loss :  tensor(0.9089)
# loss :  tensor(0.9085)
# loss :  tensor(0.9081)
# loss :  tensor(0.9077)
# loss :  tensor(0.9073)
# loss :  tensor(0.9069)
# loss :  tensor(0.9065)
# loss :  tensor(0.9061)
# loss :  tensor(0.9058)
# loss :  tensor(0.9054)
# loss :  tensor(0.9050)
# loss :  tensor(0.9046)
# loss :  tensor(0.9042)
# loss :  tensor(0.9038)
# loss :  tensor(0.9034)
# loss :  tensor(0.9031)
# loss :  tensor(0.9027)
# loss :  tensor(0.9023)
# loss :  tensor(0.9019)
# loss :  tensor(0.9015)
# loss :  tensor(0.9011)
# loss :  tensor(0.9008)
# loss :  tensor(0.9004)
# loss :  tensor(0.9000)
# loss :  tensor(0.8996)
# loss :  tensor(0.8992)
# loss :  tensor(0.8989)
# loss :  tensor(0.8985)
# loss :  tensor(0.8981)
# loss :  tensor(0.8977)
# loss :  tensor(0.8974)
# loss :  tensor(0.8970)
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(range(1000), losses)
plt.show()

# %%
hour_var = torch.Tensor([[1.0]])
print("predict 1시간 : ", model(hour_var).data[0][0] > 0.5)
# Out:
# predict 1시간 :  tensor(True)

# %%
hour_var = torch.Tensor([[7.0]])
print("predict 1시간 : ", model(hour_var).data[0][0] > 0.5)
# Out:
# predict 1시간 :  tensor(True)
